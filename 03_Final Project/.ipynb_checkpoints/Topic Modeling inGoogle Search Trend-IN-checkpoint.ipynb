# %% [markdown]
# ### Introduction
# Topic Models, in a nutshell, are a type of statistical language models used for uncovering hidden structure in a collection of texts. In a practical and more intuitively, you can think of it as a task of:
#
# - **Dimensionality Reduction**, where rather than representing a text T in its feature space as {Word_i: count(Word_i, T) for Word_i in Vocabulary}, you can represent it in a topic space as {Topic_i: Weight(Topic_i, T) for Topic_i in Topics}
# - **Unsupervised Learning**, where it can be compared to clustering, as in the case of clustering, the number of topics, like the number of clusters, is an output parameter. By doing topic modeling, we build clusters of words rather than clusters of texts. A text is thus a mixture of all the topics, each having a specific weight
# - **Tagging**, abstract “topics” that occur in a collection of documents that best represents the information in them.
#
# There are several existing algorithms you can use to perform the topic modeling. The most common of it are, Latent Semantic Analysis (LSA/LSI), Probabilistic Latent Semantic Analysis (pLSA), and Latent Dirichlet Allocation (LDA)
#
# In this tutorial, we’ll take a closer look at LDA, and implement our first topic model using the sklearn implementation in python 2.7
#
# ### Theoretical Overview
# LDA is a generative probabilistic model that assumes each topic is a mixture over an underlying set of words, and each document is a mixture of over a set of topic probabilities.
#
# ![LDA_Model](https://github.com/chdoig/pytexas2015-topic-modeling/blob/master/images/lda-4.png?raw=true)
#
# We can describe the generative process of LDA as, given the M number of documents, N number of words, and prior K number of topics, the model trains to output:
#
# - `psi`, the distribution of words for each topic K
# - `phi`, the distribution of topics for each document i
#
# #### Parameters of LDA
#
# - `Alpha parameter` is Dirichlet prior concentration parameter that represents document-topic density — with a higher alpha, documents are assumed to be made up of more topics and result in more specific topic distribution per document.
# - `Beta parameter` is the same prior concentration parameter that represents topic-word density — with high beta, topics are assumed to made of up most of the words and result in a more specific word distribution per topic.

# %% [markdown]
# ### LDA Implementation
#
# 1. Loading data
# 2. Data cleaning
# 3. Exploratory analysis
# 4. Preparing data for LDA analysis
# 5. Model Evaluation and parameter tuning

# %% [markdown]
# #### Loading data
#
# For this tutorial, we’ll use the dataset of papers published in NIPS conference. The NIPS conference (Neural Information Processing Systems) is one of the most prestigious yearly events in the machine learning community. The CSV data file contains information on the different NIPS papers that were published from 1987 until 2016 (29 years!). These papers discuss a wide variety of topics in machine learning, from neural networks to optimization methods, and many more.
#
# <img src="https://s3.amazonaws.com/assets.datacamp.com/production/project_158/img/nips_logo.png" alt="The logo of NIPS (Neural Information Processing Systems)">
#
# Let’s start by looking at the content of the file

# %%
# Importing modules
import pymongo
from pymongo import MongoClient
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Read data from MongoDB
cluster = MongoClient('mongodb+srv://rimho:0000@cluster0-yehww.mongodb.net/test?retryWrites=true&w=majority')
db = cluster['3_Google_search_trends_db']
collections = [db[c] for c in ['PH']]
documents =  [collection.find() for collection in collections]

products = []
for document in documents:
    for p in document:
        products.append(p)
table = json_normalize(products)

# # Print head
table.head()
# Out:
#                         _id country  year  category ranking        keyword  \
# 0  5dee8d212f5768b263df5984      PH  2014  Searches       1  Vhong Navarro
# 1  5dee8d212f5768b263df5985      PH  2014  Searches       1  Vhong Navarro
# 2  5dee8d212f5768b263df5986      PH  2014  Searches       1  Vhong Navarro
# 3  5dee8d212f5768b263df5987      PH  2014  Searches       1  Vhong Navarro
# 4  5dee8d212f5768b263df5988      PH  2014  Searches       1  Vhong Navarro
#
#                                                 href          region  \
# 0  https://trends.google.com/trends/explore?date=...      Region XII
# 1  https://trends.google.com/trends/explore?date=...  Cagayan Valley
# 2  https://trends.google.com/trends/explore?date=...        MIMAROPA
# 3  https://trends.google.com/trends/explore?date=...          Caraga
# 4  https://trends.google.com/trends/explore?date=...   Ilocos Region
#
#   search_volume
# 0           100
# 1            90
# 2            84
# 3            82
# 4            78

# %% [markdown]
# #### Data Cleaning
#
# Since the goal of this analysis is to perform topic modeling, we will solely focus on the text data from each paper, and drop other metadata columns

# %%
# Remove the columns
columns_name = list(table)
basic_df = table.drop(table.columns[[0, 6]], axis=1)
cols = basic_df.columns.tolist()
df = basic_df[cols]#.sort_values(by='year', ascending=False)
keyword_PH = df.loc[df['country'] == 'PH']

# Print out the first rows of papers
keyword_PH.head()
# Out:
#   country  year  category ranking        keyword          region search_volume
# 0      PH  2014  Searches       1  Vhong Navarro      Region XII           100
# 1      PH  2014  Searches       1  Vhong Navarro  Cagayan Valley            90
# 2      PH  2014  Searches       1  Vhong Navarro        MIMAROPA            84
# 3      PH  2014  Searches       1  Vhong Navarro          Caraga            82
# 4      PH  2014  Searches       1  Vhong Navarro   Ilocos Region            78

# %% [markdown]
# #### Remove punctuation/lower casing
#
# Next, let’s perform a simple preprocessing on the content of paper_text column to make them more amenable for analysis, and reliable results. To do that, we’ll use a regular expression to remove any punctuation, and then lowercase the text

# %%
# Load the regular expression library
import re

# Remove punctuation
keyword_PH['keyword_processed'] = keyword_PH['keyword'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
keyword_PH['keyword_processed'] = keyword_PH['keyword'].map(lambda x: x.lower())

# Print out the first rows of papers
keyword_PH['keyword_processed'].head()
# Out:
# 0    vhong navarro
# 1    vhong navarro
# 2    vhong navarro
# 3    vhong navarro
# 4    vhong navarro
# Name: keyword_processed, dtype: object

# %%
keyword_PH_2014 = keyword_PH.loc[df['year'] == '2014']
keyword_PH_2015 = keyword_PH.loc[df['year'] == '2015']
keyword_PH_2016 = keyword_PH.loc[df['year'] == '2016']
keyword_PH_2017 = keyword_PH.loc[df['year'] == '2017']
keyword_PH_2018 = keyword_PH.loc[df['year'] == '2018']
keyword_PH_2014
# Out:
#     country  year     category ranking            keyword           region  \
# 0        PH  2014     Searches       1      Vhong Navarro       Region XII
# 1        PH  2014     Searches       1      Vhong Navarro   Cagayan Valley
# 2        PH  2014     Searches       1      Vhong Navarro         MIMAROPA
# 3        PH  2014     Searches       1      Vhong Navarro           Caraga
# 4        PH  2014     Searches       1      Vhong Navarro    Ilocos Region
# ..      ...   ...          ...     ...                ...              ...
# 395      PH  2014  Restaurants       8          Charaptor       Calabarzon
# 396      PH  2014  Restaurants       9  La Vie Parisienne  Central Visayas
# 397      PH  2014  Restaurants      10            Kyochon     Metro Manila
# 398      PH  2014  Restaurants      10            Kyochon    Central Luzon
# 399      PH  2014  Restaurants      10            Kyochon       Calabarzon
#
#     search_volume  keyword_processed
# 0             100      vhong navarro
# 1              90      vhong navarro
# 2              84      vhong navarro
# 3              82      vhong navarro
# 4              78      vhong navarro
# ..            ...                ...
# 395            59          charaptor
# 396           100  la vie parisienne
# 397           100            kyochon
# 398            81            kyochon
# 399            56            kyochon
#
# [400 rows x 8 columns]

# %% [markdown]
# #### Exploratory Analysis
#
# To verify whether the preprocessing happened correctly, we’ll make a word cloud using the wordcloud package to get a visual representation of most common words. It is key to understanding the data and ensuring we are on the right track, and if any more preprocessing is necessary before training the model.

# %%
# Import the wordcloud library
from wordcloud import WordCloud
import matplotlib
import matplotlib.pyplot as plt

# Join the different processed titles together.
long_string = ','.join(list(keyword_PH_2014['keyword_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, colormap=matplotlib.cm.inferno)

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x10F467CF8>

# %%
long_string = ','.join(list(keyword_PH_2015['keyword_processed'].values))
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, colormap=matplotlib.cm.inferno)
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x11670D908>

# %%
long_string = ','.join(list(keyword_PH_2016['keyword_processed'].values))
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, colormap=matplotlib.cm.inferno)
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x10F47B630>

# %%
long_string = ','.join(list(keyword_PH_2017['keyword_processed'].values))
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, colormap=matplotlib.cm.inferno)
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x10F4814E0>

# %%
long_string = ','.join(list(keyword_PH_2018['keyword_processed'].values))
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, colormap=matplotlib.cm.inferno)
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x10F47B0F0>

# %% [markdown]
# #### Prepare text for LDA analysis
#
# Next, let’s work to transform the textual data in a format that will serve as an input for training LDA model. We start by converting the documents into a simple vector representation (Bag of Words BOW). Next, we will convert a list of titles into lists of vectors, all with length equal to the vocabulary.
#
# We’ll then plot the ten most frequent words based on the outcome of this operation (the list of document vectors). As a check, these words should also occur in the word cloud.

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette="gist_heat")
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
    print(words)

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(keyword_PH_2018['keyword_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# ['2018', 'nba', 'cup', 'gamers', 'garden', 'hot', 'lotto', 'love', 'lyrics', 'memoryhackers']

# %%
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(keyword_PH_2017['keyword_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# ['miss', 'oppo', 'universe', 'park', '13', '2017', 'asia', 'baby', 'beast', 'beauty']

# %%
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(keyword_PH_2016['keyword_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# ['2016', 'love', 'song', 'election', 'pokemon', 'away', 'busan', 'closer', 'duterte', 'games']

# %%
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(keyword_PH_2015['keyword_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# ['2015', 'apec', 'francis', 'pope', 'love', 'summit', 'google', 'dubsmash', 'clans', 'clash']

# %%
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(keyword_PH_2014['keyword_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# ['2014', 'vs', 'cup', 'world', 'bediones', 'big', 'bird', 'cedric', 'flappy', 'frozen']

# %%
keyword_PH_2018.loc[keyword_PH_2018['keyword_processed'].str.contains('memoryhackers', regex=False)]
# Out:
#      country  year                   category ranking        keyword  \
# 1913      PH  2018  Overall Trending Searches       1  MemoryHackers
# 1914      PH  2018  Overall Trending Searches       1  MemoryHackers
# 1915      PH  2018  Overall Trending Searches       1  MemoryHackers
# 1916      PH  2018  Overall Trending Searches       1  MemoryHackers
# 1917      PH  2018  Overall Trending Searches       1  MemoryHackers
# 2247      PH  2018                      Games       1  MemoryHackers
# 2248      PH  2018                      Games       1  MemoryHackers
# 2249      PH  2018                      Games       1  MemoryHackers
# 2250      PH  2018                      Games       1  MemoryHackers
# 2251      PH  2018                      Games       1  MemoryHackers
#
#                                     region search_volume keyword_processed
# 1913                            Region XII           100     memoryhackers
# 1914                     Northern Mindanao            85     memoryhackers
# 1915                          Davao Region            70     memoryhackers
# 1916  Autonomous Region in Muslim Mindanao            65     memoryhackers
# 1917                                Caraga            57     memoryhackers
# 2247                            Region XII           100     memoryhackers
# 2248                     Northern Mindanao            86     memoryhackers
# 2249                          Davao Region            70     memoryhackers
# 2250  Autonomous Region in Muslim Mindanao            63     memoryhackers
# 2251                                Caraga            56     memoryhackers

# %%
['2018', 'nba', 'cup', 'gamers', 'garden', 'hot', 'lotto', 'love', 'lyrics', 'memoryhackers']
# Out:
# ['2016',
#  'love',
#  'song',
#  'election',
#  'pokemon',
#  'away',
#  'busan',
#  'closer',
#  'duterte',
#  'games']

# %%
PH_top_30 = ['love', '2018', '2016', 'cup', '2014', 'vs', 'nba', 'world', 'voice', '2015', 'playoffs', 'google', 'sona', 'games', 'pacquiao', 'fiba', 'asia', 'garden', 'lee', 'lyrics', 'meteor', 'miss', 'new', 'perfect', 'saga', 'song', 'summit', 'universe', 'apec', 'francis']

# %%
def find_category(df, arr):
    new_arr = []
    for kw in arr:
        collection = {}
        new_df = df.loc[df['keyword_processed'].str.contains(kw, regex=False)]
        new_df = new_df.loc[new_df['search_volume'] == '100']
        collection['keyword'] = kw
        collection['year'] = list(new_df['year'])
        collection['category'] = list(new_df['category'])
        collection['all_keyword'] = list(new_df['keyword'])
        collection['region'] = list(new_df['region'])
        new_arr.append(collection)
    return new_arr

# %%
results = find_category(keyword_PH, PH_top_30)
dicts = {}
for arr in results_df['region']:
    for city in arr:
        if city not in dicts:
            dicts[city] = 1
        else:
            dicts[city] = dicts[city] + 1
dict
# Out:
#      keyword                                               year  \
# 0       love  2015,2015,2015,2016,2016,2016,2016,2016,2016,2...
# 1       2018  2018,2018,2018,2018,2018,2018,2018,2018,2018,2...
# 2       2016  2016,2016,2016,2016,2016,2016,2016,2016,2016,2...
# 3        cup            2014,2014,2014,2015,2017,2017,2018,2018
# 4       2014            2014,2014,2014,2014,2014,2014,2014,2014
# 5         vs       2014,2014,2014,2016,2016,2017,2017,2018,2018
# 6        nba                      2015,2016,2017,2018,2018,2018
# 7      world                 2014,2014,2014,2015,2015,2018,2018
# 8      voice                      2014,2014,2015,2015,2017,2017
# 9       2015                           2015,2015,2015,2015,2015
# 10  playoffs                           2015,2016,2017,2018,2018
# 11    google                           2015,2015,2015,2016,2016
# 12      sona                           2014,2015,2016,2017,2018
# 13     games                      2014,2015,2016,2016,2018,2018
# 14  pacquiao                 2014,2014,2015,2016,2016,2017,2018
# 15      fiba                           2014,2015,2015,2017,2017
# 16      asia                 2014,2015,2015,2017,2017,2018,2018
# 17    garden                                2014,2014,2018,2018
# 18       lee                      2014,2014,2016,2017,2017,2018
# 19    lyrics                                2017,2017,2018,2018
# 20    meteor                                2014,2014,2018,2018
# 21      miss                                2015,2017,2017,2017
# 22       new                                2015,2016,2016,2017
# 23   perfect                                2015,2017,2017,2018
# 24      saga                                2014,2017,2018,2018
# 25      song                                2016,2016,2016,2016
# 26    summit                                2015,2015,2015,2017
# 27  universe                                2015,2017,2017,2017
# 28      apec                           2015,2015,2015,2015,2015
# 29   francis                                2015,2015,2015,2015
#
#                                              category  \
# 0   Songs (Lyrics),TV Shows,TV Shows,Top Trending ...
# 1   Overall Trending Searches,Overall Trending Sea...
# 2   Top Trending Searches (Overall),Events,Events,...
# 3   Events,Events,Mobile Searches,Events,Overall S...
# 4   Events,Events,Events,Events,Events,Events,Mobi...
# 5   Events,Events,Events,Events,Events,Events,Even...
# 6   Events,Events,Events,Overall Trending Searches...
# 7   Events,Events,Mobile Searches,Movies,Who is......
# 8   TV Shows,TV Shows,TV Shows,TV Shows,Overall Se...
# 9                Searches,Searches,Events,Events,News
# 10  Events,Events,Events,Overall Trending Searches...
# 11                      Apps,Apps,Apps,Apps,How to...
# 12                       News,Events,Events,News,News
# 13  Events,Events,Top Trending Searches (Overall),...
# 14  Events,Events,Male Personalities,Events,Events...
# 15     Events,Searches,Events,Overall Searches,Events
# 16  Events,Searches,Events,Overall Searches,Events...
# 17  Searches,TV Shows,Overall Trending Searches,TV...
# 18  Searches,Newsmakers,Female Personalities,Femal...
# 19  Overall Searches,Overall Searches,Overall Tren...
# 20  Searches,TV Shows,Overall Trending Searches,TV...
# 21              Events,Overall Searches,Events,Events
# 22  Events,Events,Vacation Destinations (Internati...
# 23  Movies,Overall Searches,Songs and Lyrics,Overa...
# 24          Apps,Apps,Overall Trending Searches,Games
# 25  Top Trending Searches (Overall),Male Personali...
# 26                        Searches,Events,News,Events
# 27              Events,Overall Searches,Events,Events
# 28       Searches,Events,News,What is...?,What is...?
# 29        Searches,Male Personalities,Who is...?,News
#
#                                           all_keyword  \
# 0   Love Me Like You Do,On the Wings of Love,My Lo...
# 1   NBA Playoffs 2018,Meteor Garden 2018,NBA Playo...
# 2   Olympic Games Rio 2016,Olympic Games Rio 2016,...
# 3   FIFA World Cup 2014,FIBA World Cup 2014,World ...
# 4   FIFA World Cup 2014,FIBA World Cup 2014,Asian ...
# 5   Pacquiao vs Algieri,Pacquiao vs Bradley,Maywea...
# 6   NBA Playoffs,NBA Playoffs 2016,NBA Playoffs,NB...
# 7   FIFA World Cup 2014,FIBA World Cup 2014,World ...
# 8   The Voice Kids,The Voice of the Philippines,Th...
# 9   FIBA Asia 2015,APEC Summit 2015,FIBA Asia 2015...
# 10  NBA Playoffs,NBA Playoffs 2016,NBA Playoffs,NB...
# 11  Google App,Google Street View,Google Translate...
# 12            SONA 2014,SONA,SONA 2016,SONA,SONA 2018
# 13  Asian Games 2014,SEA Games,Olympic Games Rio 2...
# 14  Pacquiao vs Algieri,Pacquiao vs Bradley,Manny ...
# 15  FIBA World Cup 2014,FIBA Asia 2015,FIBA Asia 2...
# 16  Asian Games 2014,FIBA Asia 2015,FIBA Asia 2015...
# 17  Meteor Garden,Meteor Garden,Meteor Garden 2018...
# 18  Cedric Lee,Cedric Lee,Hailee Steinfeld,Lee Sun...
# 19  Despacito lyrics,Versace on the Floor lyrics,H...
# 20  Meteor Garden,Meteor Garden,Meteor Garden 2018...
# 21  Miss Universe,Miss Universe 2017,Miss Universe...
# 22  Chinese New Year,Chinese New Year 2016,Papua N...
# 23     Pitch Perfect 2,Perfect,Perfect,Perfect lyrics
# 24  Candy Crush Saga,Summertime Saga,Summertime Sa...
# 25  Secret Love Song,Song Joong Ki,Song Hye Kyo,Se...
# 26  APEC Summit 2015,APEC Summit 2015,APEC Summit ...
# 27  Miss Universe,Miss Universe 2017,Miss Universe...
# 28  APEC Summit 2015,APEC Summit 2015,APEC Summit ...
# 29  Pope Francis,Pope Francis,Who is Pope Francis?...
#
#                                                region
# 0   Cordillera Administrative Region,Cagayan Valle...
# 1   Zamboanga Peninsula,Cagayan Valley,Zamboanga P...
# 2   Eastern Visayas,Eastern Visayas,Cagayan Valley...
# 3   Western Visayas,Eastern Visayas,Caraga,Eastern...
# 4   Western Visayas,Eastern Visayas,Caraga,Bicol,R...
# 5   Eastern Visayas,Northern Mindanao,Region XII,C...
# 6   Cordillera Administrative Region,Ilocos Region...
# 7   Western Visayas,Eastern Visayas,Caraga,Cagayan...
# 8   Cagayan Valley,Bicol,MIMAROPA,Cagayan Valley,C...
# 9   Eastern Visayas,Eastern Visayas,Eastern Visaya...
# 10  Cordillera Administrative Region,Ilocos Region...
# 11  Bicol,Calabarzon,Calabarzon,Metro Manila,Zambo...
# 12           Caraga,Bicol,Eastern Visayas,Bicol,Bicol
# 13  Caraga,Cordillera Administrative Region,Easter...
# 14  Eastern Visayas,Northern Mindanao,Eastern Visa...
# 15  Eastern Visayas,Eastern Visayas,Eastern Visaya...
# 16  Caraga,Eastern Visayas,Eastern Visayas,Region ...
# 17         Caraga,Bicol,Cagayan Valley,Cagayan Valley
# 18  Eastern Visayas,Eastern Visayas,Caraga,Bicol,E...
# 19  Cagayan Valley,Ilocos Region,Region XII,Cagaya...
# 20         Caraga,Bicol,Cagayan Valley,Cagayan Valley
# 21  Zamboanga Peninsula,Region XII,Region XII,Zamb...
# 22  Cordillera Administrative Region,Eastern Visay...
# 23  Cordillera Administrative Region,Cagayan Valle...
# 24  Region XII,Calabarzon,Autonomous Region in Mus...
# 25  MIMAROPA,Eastern Visayas,Cordillera Administra...
# 26  Eastern Visayas,Eastern Visayas,Ilocos Region,...
# 27  Zamboanga Peninsula,Region XII,Region XII,Zamb...
# 28  Eastern Visayas,Eastern Visayas,Ilocos Region,...
# 29  Cordillera Administrative Region,Cordillera Ad...

# %%
# Out:
# {'Cordillera Administrative Region,Cagayan Valley,Eastern Visayas,Bicol,Cagayan Valley,MIMAROPA,Cagayan Valley,MIMAROPA,Zamboanga Peninsula,Cagayan Valley,Bicol,Autonomous Region in Muslim Mindanao,Calabarzon': 1,
#  'Zamboanga Peninsula,Cagayan Valley,Zamboanga Peninsula,Ilocos Region,Eastern Visayas,Caraga,Zamboanga Peninsula,Caraga,Cagayan Valley,Bicol,Caraga': 1,
#  'Eastern Visayas,Eastern Visayas,Cagayan Valley,Eastern Visayas,MIMAROPA,Eastern Visayas,Eastern Visayas,Ilocos Region,Eastern Visayas,Cagayan Valley,Eastern Visayas,Zamboanga Peninsula': 1,
#  'Western Visayas,Eastern Visayas,Caraga,Eastern Visayas,Region XII,Region XII,Western Visayas,Western Visayas': 1,
#  'Western Visayas,Eastern Visayas,Caraga,Bicol,Region XII,Northern Mindanao,Caraga,Caraga': 1,
#  'Eastern Visayas,Northern Mindanao,Region XII,Caraga,Eastern Visayas,Metro Manila,Cagayan Valley,Metro Manila,Cagayan Valley': 1,
#  'Cordillera Administrative Region,Ilocos Region,Autonomous Region in Muslim Mindanao,Zamboanga Peninsula,Zamboanga Peninsula,Ilocos Region': 1,
#  'Western Visayas,Eastern Visayas,Caraga,Cagayan Valley,Central Visayas,Western Visayas,Western Visayas': 1,
#  'Cagayan Valley,Bicol,MIMAROPA,Cagayan Valley,Caraga,Caraga': 1,
#  'Eastern Visayas,Eastern Visayas,Eastern Visayas,Eastern Visayas,Ilocos Region': 1,
#  'Cordillera Administrative Region,Ilocos Region,Autonomous Region in Muslim Mindanao,Zamboanga Peninsula,Zamboanga Peninsula': 1,
#  'Bicol,Calabarzon,Calabarzon,Metro Manila,Zamboanga Peninsula': 1,
#  'Caraga,Bicol,Eastern Visayas,Bicol,Bicol': 1,
#  'Caraga,Cordillera Administrative Region,Eastern Visayas,Eastern Visayas,Eastern Visayas,Caraga': 1,
#  'Eastern Visayas,Northern Mindanao,Eastern Visayas,Caraga,Eastern Visayas,Metro Manila,Metro Manila': 1,
#  'Eastern Visayas,Eastern Visayas,Eastern Visayas,Region XII,Region XII': 1,
#  'Caraga,Eastern Visayas,Eastern Visayas,Region XII,Region XII,Eastern Visayas,Caraga': 1,
#  'Caraga,Bicol,Cagayan Valley,Cagayan Valley': 2,
#  'Eastern Visayas,Eastern Visayas,Caraga,Bicol,Eastern Visayas,Metro Manila': 1,
#  'Cagayan Valley,Ilocos Region,Region XII,Cagayan Valley': 1,
#  'Zamboanga Peninsula,Region XII,Region XII,Zamboanga Peninsula': 2,
#  'Cordillera Administrative Region,Eastern Visayas,Cagayan Valley,Metro Manila': 1,
#  'Cordillera Administrative Region,Cagayan Valley,Cagayan Valley,Cagayan Valley': 1,
#  'Region XII,Calabarzon,Autonomous Region in Muslim Mindanao,Autonomous Region in Muslim Mindanao': 1,
#  'MIMAROPA,Eastern Visayas,Cordillera Administrative Region,MIMAROPA': 1,
#  'Eastern Visayas,Eastern Visayas,Ilocos Region,Metro Manila': 1,
#  'Eastern Visayas,Eastern Visayas,Ilocos Region,Cagayan Valley,Region XII': 1,
#  'Cordillera Administrative Region,Cordillera Administrative Region,Cordillera Administrative Region,Cordillera Administrative Region': 1}

# %%
results_df.loc[results_df['region'].str.contains('Sindh', regex=False)]

# %%
total = 9
target = 7
(1-((total - target)/total)) *100

# %% [markdown]
# ### LDA model tranining
#
# To keep things simple, we will only tweak the number of topic parameters.

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below (use int values below 15)
number_topics = 5
number_words = 30

# Create and fit the LDA model
lda = LDA(n_components=number_topics)
lda.fit(count_data)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# big navarro vhong 2014 pacquiao brother pinoy algieri father day hero malaysia airlines ronin 47 oscars divergent godzilla vs ihop baler costa pacifica anning mary pie project mall fisher cinema
#
# Topic #1:
# 2014 ebola virus philippine arena gahol bryan cabanero roxanne jennifer lawrence wimbledon isis ball cyrus miley wrecking sona asian games transformation makeup kyochon glenda typhoon la vie parisienne caliburger makati
#
# Topic #2:
# vs meteor garden williams robin blank taylor space swift mayweather maidana bradley vikings got believe legal wife paul george john legend philippines keyboard retrica maleficent voice pacquiao city manila dreams
#
# Topic #3:
# flappy bird frozen voice michael christian martinez saga candy crush empress ki truth naked deniece cornejo angel eyes kids psiphon spotify stay iphone bonzo ann michelle sky ranch tagaytay perry
#
# Topic #4:
# cup world 2014 lee cedric paolo bediones fifa royals lorde ikaw lamang helena belmonte poklonskaya natalia starting heirs mh17 annabelle mobogenie darren espanto ukraine charaptor stars counting onerepublic eastwood buffet

# %% [markdown]
# ### Analyzing our LDA model
#
# Now that we have a trained model let’s visualize the topics for interpretability. To do so, we’ll use a popular visualization package, pyLDAvis which is designed to help interactively with:
#
# 1. Better understanding and interpreting individual topics, and
# 2. Better understanding the relationships between the topics.
#
# For (1), you can manually select each topic to view its top most frequent and/or “relevant” terms, using different values of the λ parameter. This can help when you’re trying to assign a human interpretable name or “meaning” to each topic.
# For (2), exploring the Intertopic Distance Plot can help you learn about how topics relate to each other, including potential higher-level structure between groups of topics.

# %%
# !pip3 install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (2.1.2)
# Requirement already satisfied: numexpr in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (2.7.0)
# Requirement already satisfied: future in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: scipy>=0.18.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (1.3.1)
# Requirement already satisfied: wheel>=0.23.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (0.33.6)
# Requirement already satisfied: jinja2>=2.7.2 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (2.10.1)
# Requirement already satisfied: joblib>=0.8.4 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (0.14.0)
# Requirement already satisfied: numpy>=1.9.2 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (1.17.2)
# Requirement already satisfied: pytest in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (5.3.1)
# Requirement already satisfied: pandas>=0.17.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (0.25.1)
# Requirement already satisfied: funcy in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyLDAvis) (1.14)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: wcwidth in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (0.1.7)
# Requirement already satisfied: packaging in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (19.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (19.2.0)
# Requirement already satisfied: py>=1.5.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (1.8.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (8.0.2)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (0.13.1)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pytest->pyLDAvis) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pandas>=0.17.0->pyLDAvis) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pandas>=0.17.0->pyLDAvis) (2019.2)
# Requirement already satisfied: six in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from packaging->pytest->pyLDAvis) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from packaging->pytest->pyLDAvis) (2.4.2)
# Requirement already satisfied: zipp>=0.5 in /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->pyLDAvis) (0.6.0)

# %%
# %%time

from pyLDAvis import sklearn as sklearn_lda
import pickle 
import pyLDAvis
import os

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_data_filepath = os.path.join('./ldavis_prepared_'+str(number_topics))
# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:

    LDAvis_prepared = sklearn_lda.prepare(lda, count_data, count_vectorizer)

    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)
        
# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, "rb") as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, './ldavis_prepared_'+ str(number_topics) +'.html')

LDAvis_prepared
# Out:
# CPU times: user 610 ms, sys: 114 ms, total: 724 ms
# Wall time: 10.8 s
# /Users/hh/.pyenv/versions/3.6.7/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.186632  0.182346       1        1  22.566270
# 4     -0.210873 -0.042344       2        1  21.853990
# 3      0.169807 -0.237348       3        1  20.517605
# 0     -0.041502  0.119445       4        1  18.669898
# 1     -0.104064 -0.022099       5        1  16.392237, topic_info=    Category       Freq        Term      Total  loglift  logprob
# 1    Default  28.000000        2014  28.000000  30.0000  30.0000
# 18   Default   9.000000         big   9.000000  29.0000  29.0000
# 169  Default   9.000000       vhong   9.000000  28.0000  28.0000
# 120  Default   9.000000     navarro   9.000000  27.0000  27.0000
# 179  Default   9.000000       world   9.000000  26.0000  26.0000
# ..       ...        ...         ...        ...      ...      ...
# 129   Topic5   1.025989  parisienne   1.672296   1.3198  -4.8431
# 170   Topic5   1.025989         vie   1.672296   1.3198  -4.8431
# 28    Topic5   1.025906  caliburger   1.672291   1.3197  -4.8431
# 99    Topic5   1.025906      makati   1.672291   1.3197  -4.8431
# 1     Topic5  10.450055        2014  28.145720   0.8176  -2.5221
#
# [189 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 0         2  0.830620        101
# 1         2  0.319764       2014
# 1         4  0.284235       2014
# 1         5  0.355294       2014
# 2         4  0.606347       2048
# ...     ...       ...        ...
# 176       1  0.824925       wife
# 177       1  0.884134   williams
# 178       5  0.785489  wimbledon
# 179       2  0.940895      world
# 180       5  0.943986   wrecking
#
# [162 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 5, 4, 1, 2])

# %% [markdown]
# ### Closing Notes
# Machine learning has become increasingly popular over the past decade, and recent advances in computational availability have led to exponential growth to people looking for ways how new methods can be incorporated to advance the field of Natural Language Processing.
#
# Often, we treat topic models as black-box algorithms, but hopefully, this post addressed to shed light on the underlying math, and intuitions behind it, and high-level code to get you started with any textual data.
#
# In the next article, we’ll go one step deeper into understanding how you can evaluate the performance of topic models, tune its hyper-parameters to get more intuitive and reliable results.
#
# ** **
# #### Sources:
# 1. Topic model — Wikipedia. https://en.wikipedia.org/wiki/Topic_model
# 2. Distributed Strategies for Topic Modeling. https://www.ideals.illinois.edu/bitstream/handle/2142/46405/ParallelTopicModels.pdf?sequence=2&isAllowed=y
# 3. Topic Mapping — Software — Resources — Amaral Lab. https://amaral.northwestern.edu/resources/software/topic-mapping
# 4. A Survey of Topic Modeling in Text Mining. https://thesai.org/Downloads/Volume6No1/Paper_21-A_Survey_of_Topic_Modeling_in_Text_Mining.pdf
